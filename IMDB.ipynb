# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
title_basic_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
title_aka_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
title_rating_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(title_basic_url, sep='\t', low_memory=False)

# %%
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8899038  tt9916848  tvEpisode              Episode #3.17
# 8899039  tt9916850  tvEpisode              Episode #3.19
# 8899040  tt9916852  tvEpisode              Episode #3.20
# 8899041  tt9916856      short                   The Wind
# 8899042  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8899038              Episode #3.17       0      2010      \N             \N
# 8899039              Episode #3.19       0      2010      \N             \N
# 8899040              Episode #3.20       0      2010      \N             \N
# 8899041                   The Wind       0      2015      \N             27
# 8899042  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8899038         Action,Drama,Family
# 8899039         Action,Drama,Family
# 8899040         Action,Drama,Family
# 8899041                       Short
# 8899042  Adventure,Animation,Comedy
#
# [8899043 rows x 9 columns]

# %%
basics_df = basics.replace({'\\N':np.nan})

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8899043 entries, 0 to 8899042
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 611.0+ MB

# %%
basics_df = basics_df.dropna(subset = ['runtimeMinutes', 'genres'])

# %%
basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2330718 entries, 0 to 8899042
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 177.8+ MB

# %%
movie_filter = basics_df['titleType'] == 'movie'

# %%
basics_df = basics_df[movie_filter]

# %%
basics_df.head()
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 570      The Story of the Kelly Gang       0      1906     NaN             70
# 587                L'enfant prodigue       0      1907     NaN             90
# 672   The Fairylogue and Radio-Plays       0      1908     NaN            120
# 1172         Don Juan de Serrallonga       0      1910     NaN             58
# 1273               The Life of Moses       0      1909     NaN             50
#
#                           genres
# 570   Action,Adventure,Biography
# 587                        Drama
# 672            Adventure,Fantasy
# 1172             Adventure,Drama
# 1273      Biography,Drama,Family

# %%
import os
os.makedirs('Data/', exist_ok=True)
os.listdir("Data/")
# Out:
# ['title_basics.csv.gz']

# %%
basics_df.to_csv("Data/title_basics.csv.gz", compression='gzip',index=False)

# %%
del basics_df

# %%
aka = pd.read_csv(title_aka_url, sep='\t', low_memory=False)

# %%
aka
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 31866469  tt9916852         5             Episódio #3.20     PT       pt
# 31866470  tt9916852         6             Episodio #3.20     IT       it
# 31866471  tt9916852         7               एपिसोड #3.20     IN       hi
# 31866472  tt9916856         1                   The Wind     DE       \N
# 31866473  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 31866469           \N             \N               0
# 31866470           \N             \N               0
# 31866471           \N             \N               0
# 31866472  imdbDisplay             \N               0
# 31866473     original             \N               1
#
# [31866474 rows x 8 columns]

# %%
aka_df = aka.replace({'\\N':np.nan})

# %%
is_US = aka_df['region'] == 'US'

# %%
aka_df = aka_df[is_US]

# %%
aka_df.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
aka_df.to_csv("Data/aka.csv.gz", compression='gzip',index=False)

# %%
del aka_df

# %%
rating = pd.read_csv(title_rating_url, sep='\t', low_memory=False)

# %%
rating_df = rating.replace({'\\N':np.nan})

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241511 entries, 0 to 1241510
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1241511 non-null  object
#  1   averageRating  1241511 non-null  float64
#  2   numVotes       1241511 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.4+ MB

# %%
rating_df.to_csv("Data/rating.csv.gz", compression='gzip',index=False)
